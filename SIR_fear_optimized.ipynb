# %% [markdown]
# # SIR model on a network with characterization of Behavior and Age Classes
# In this notebook we aim to build a network starting from real data that represents a population of **N** individuals and is structured similarly to Italian population. We start from real available data on age and contacts and use them to build the network properly. Then we define a custom SEIR model with Gillespie algorithm that handles both the SEIR dynamics on the network and the transmission of fear.
#
# Our choice for behavioral characterization is the introduction of a percepted fear, that is a scalar assigned to each node, that if goes above a threshold changes the way such node interacts on the network, reducing its capability of making successful contacts. Hence our model is a mixture of a Epidemic model on a network and a complex contagion model for fear.
#
# First off we import the desired **libraries**

# %%
import numpy as np
import pandas as pd
import kagglehub
import os
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, CenteredNorm
import networkx as nx
import EoN
import igraph as ig
from PIL import Image
from tqdm import tqdm

# make a dir to save everything
os.makedirs(f'SIR', exist_ok = True)
gif_flag = False

# %% [markdown]
# ## Functions
# We define here some useful function of our code:
# - **draw_function(G)**: this function draws the network G according to the features of the nodes. Each color reèresents a state towards the disease, while the shape of the node represents the age class. **S** and **Sf** classes depend on fear level, if an individual is S and has a fear above the threshold it becomes a Sf individual
# - **node_age_counter(G)**: this function counts how many nodes are in each age class
# - **save_plot(G,time,filepath,pos)**: this function draws the graph G that is produced at a given time and with specified position pos. We shall use always the same pos once our first graph is created to both reduce computation time and make consistent plots

# %%
# draw func

def draw_function(G, path_save_plot):
    # Color by disease state
    disease_color_map = {'S': 'blue','Sf':'lightblue', 'I': 'red', 'R': 'green'}
    node_colors = [disease_color_map[G.nodes[node]['disease_state']] for node in G.nodes()]
    
    # Shape by age class
    age_shape_map = {'A': 'o', 'E': 's', 'Y': '^'}  # o=circle, s=square, ^=triangle
    
    pos = nx.arf_layout(G)
    
    # Draw nodes by age class (different shapes)
    for age_class, shape in age_shape_map.items():
        # Get nodes with this age class
        nodes_in_class = [node for node in G.nodes() if G.nodes[node]['age_class'] == age_class]
        # Get their colors based on disease state
        colors_in_class = [disease_color_map[G.nodes[node]['disease_state']] for node in nodes_in_class]
        # Get their positions
        pos_in_class = {node: pos[node] for node in nodes_in_class}
        
        # Draw this subset
        nx.draw_networkx_nodes(G, pos=pos_in_class, nodelist=nodes_in_class,
                               node_color=colors_in_class, node_size=int(10000/len(G.nodes)), 
                               node_shape=shape)
    
    # Draw edges once
    nx.draw_networkx_edges(G, pos=pos, width=0.1, alpha=0.5)
    
    # Optional: add legend
    from matplotlib.lines import Line2D
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=8, label='S'),
        Line2D([0], [0], marker='o', color='w', markerfacecolor='lightblue', markersize=8, label='Sf'),
        Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=8, label='I'),
        Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=8, label='R'),
        Line2D([0], [0], marker='o', color='w', markerfacecolor='gray', markersize=8, label='Adult'),
        Line2D([0], [0], marker='s', color='w', markerfacecolor='gray', markersize=8, label='Elderly'),
        Line2D([0], [0], marker='^', color='w', markerfacecolor='gray', markersize=8, label='Young'),
    ]
    plt.legend(handles=legend_elements, loc='best')
    
    plt.axis('off')
    if (path_save_plot):
        plt.savefig(path_save_plot)
    plt.show()

# function that counts how many nodes for each class
def node_age_counter(G):
    nodes_counter = {
        'A':0,
        'E':0,
        'Y':0
    }
    for i in range (len(G.nodes)):
        node = G.nodes[i]
        nodes_counter[node['age_class']]+=1
    return nodes_counter

# funct to save plot to
def save_plot(G,time,filepath,pos):
    # Color by disease state
    disease_color_map = {'S': 'blue','Sf':'lightblue', 'I': 'red', 'R': 'green'}
    node_colors = [disease_color_map[G.nodes[node]['disease_state']] for node in G.nodes()]
    
    # Shape by age class
    age_shape_map = {'A': 'o', 'E': 's', 'Y': '^'}  # o=circle, s=square, ^=triangle
     
    # Draw nodes by age class (different shapes)
    for age_class, shape in age_shape_map.items():
        # Get nodes with this age class
        nodes_in_class = [node for node in G.nodes() if G.nodes[node]['age_class'] == age_class]
        # Get their colors based on disease state
        colors_in_class = [disease_color_map[G.nodes[node]['disease_state']] for node in nodes_in_class]
        # Get their positions
        pos_in_class = {node: pos[node] for node in nodes_in_class}
        
        # Draw this subset
        nx.draw_networkx_nodes(G, pos=pos_in_class, nodelist=nodes_in_class,
                               node_color=colors_in_class, node_size=30, 
                               node_shape=shape)
    
    # Draw edges once
    nx.draw_networkx_edges(G, pos=pos, width=0.1, alpha=0.3)
    
    # Optional: add legend
    from matplotlib.lines import Line2D
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=8, label='S'),
        Line2D([0], [0], marker='o', color='w', markerfacecolor='lightblue', markersize=8, label='Sf'),
        Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markersize=8, label='I'),
        Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=8, label='R'),
        Line2D([0], [0], marker='o', color='w', markerfacecolor='gray', markersize=8, label='Adult'),
        Line2D([0], [0], marker='s', color='w', markerfacecolor='gray', markersize=8, label='Elderly'),
        Line2D([0], [0], marker='^', color='w', markerfacecolor='gray', markersize=8, label='Young'),
    ]
    #plt.legend(handles=legend_elements, loc='best')
    plt.title(f'Time-Step = {time}')
    plt.axis('off')
    plt.savefig(filepath)
    plt.close()

# %% [markdown]
# ## Network building
# Now we build our network. We start from a fully connected batch and then remove edges randomly from such batch until a specific fraction of edges is present. This is done to achieve a more realistic network rather than a fully connected initial batch, that is surely unrealistic.
#
# ### RESTART FROM THIS CELL TO RERUN EPIDEMICS

# %%
# function to create the graph according to the data we have
def graph_setupper(final_N,
              I0,
              fear_threshold):
    # start from a fully connected initial network (built according to the data of ages and contacts)
    # A, E, Y
    pops_prop = [0.5941353286169919,0.24706405947019197,0.15880061191281614]
    norm_contacts_matrix = pd.read_csv("norm_contacts_matrix.csv", index_col = 0).values.astype(float)
    
    # initial fully connected build
    # initial fear data distribution
    fear_mu = [0.1,0.2,0.2]
    fear_sigma = [0.03,0.07,0.03]

    # start from a clique of 3 nodes, 1 per class
    G = nx.Graph()
    
    age_class = 'A'
    fear = np.random.normal(fear_mu[0],fear_sigma[0])
    G.add_node(0, age_class = age_class, disease_state = 'S', fear = fear)
    age_class = 'E'
    fear = np.random.normal(fear_mu[1],fear_sigma[1])
    G.add_node(1, age_class = age_class, disease_state = 'S', fear = fear)
    age_class = 'Y'       
    fear = np.random.normal(fear_mu[2],fear_sigma[2])
    G.add_node(2, age_class = age_class, disease_state = 'S', fear = fear)
        
    # the initial setup is a FULLY CONNECTED
    edges = []
    for i in range(len(G.nodes)):
        for j in range(len(G.nodes)):
            if i!=j:
                edges.append((i,j))
    G.add_edges_from(edges)
    
    # Remove randomly some edges to make it realistic
    total_edges = G.number_of_edges()
    target_edges = int(total_edges * 0.1)  # Keep 10% of edges
    edges_to_remove = total_edges - target_edges
    
    # Get list of all edges and randomly sample which ones to remove
    all_edges = list(G.edges())
    edges_removed = np.random.choice(len(all_edges), size=edges_to_remove, replace=False)
    
    for idx in edges_removed:
        u, v = all_edges[idx]
        G.remove_edge(u, v)

    # prob dict 
    # average links to sample from by class
    avg_links = {
        'A': 12,
        'E': 6,
        'Y': 20
    }
    # std for such average (sampling)
    std_links = {
        'A': 3,
        'E': 1,
        'Y': 3
    }
    
    ages=np.array(['A','E','Y'])

    starting_N = 3  # FIX: Define starting_N since we start with 3 nodes
    
    for i in range(starting_N, final_N):
        # Randomly assign age class to new node based on population distribution
        r = np.random.uniform(0,1)
        if r < pops_prop[0]:
            age_class = 'A'
            fear = np.random.normal(fear_mu[0],fear_sigma[0])
        elif r < (pops_prop[0]+pops_prop[1]):
            age_class = 'E'
            fear = np.random.normal(fear_mu[1],fear_sigma[1])
        else:
            age_class = 'Y'
            fear = np.random.normal(fear_mu[2],fear_sigma[2])
        
        # consistency check
        fear = min(fear,1)
        fear = max(fear,0)
        
        # Add the new node with its age class
        G.add_node(i, age_class=age_class, disease_state = 'S', fear = fear)
        
        # Sample number of links from normal distribution based on age class
        n_links = max(1, int(np.random.normal(avg_links[age_class], std_links[age_class])))
    
        link=0
        connected_nodes=[]
        if age_class=='A':
            idx=0
        elif age_class=='E':
            idx=1
        else:
            idx=2
        
        # FIX: Track failed attempts to avoid infinite loop
        max_attempts = 100  # Maximum attempts to find a valid connection
        attempts = 0
            
        while link < n_links and attempts < max_attempts:
            attempts += 1
            
            # select an age group based on contact probabilities
            target_age_probs = norm_contacts_matrix[idx]
            target_age = np.random.choice(ages, p=target_age_probs)
            
            # Get all nodes of the target age (excluding the current node)
            target_nodes = [node for node in G.nodes if G.nodes[node]['age_class'] == target_age and node != i]
            
            # FIX: Check if there are no available nodes
            if len(target_nodes) == 0:
                continue  # Try another age group
            
            # FIX: Check if all available nodes are already connected
            available_nodes = [node for node in target_nodes if node not in connected_nodes]
            if len(available_nodes) == 0:
                continue  # No more nodes available in this age group
            
            # degree of each potential target node for linking probability
            K = [G.degree(node) for node in available_nodes]
            K = np.array(K, dtype=float)
            total_degree = sum(K)
    
            # FIX: Handle case where all nodes have degree 0
            if total_degree == 0:
                link_prob = np.ones(len(K)) / len(K)
            else:
                link_prob = K/total_degree
    
            # Choose a node and add edge
            linked_node = np.random.choice(available_nodes, p=link_prob)
            connected_nodes.append(linked_node)
            G.add_edge(i, linked_node)
            link += 1
            attempts = 0  # Reset attempts after successful connection
    
    # initial feared check
    for i in range(len(G.nodes)):
        if(G.nodes[i]['fear']>fear_threshold):
            G.nodes[i]['disease_state'] = 'Sf'

    # some population will be infected at start
    N = len(G.nodes)
        
    # initial nodes infected are assigned here
    I_indices = np.random.choice(range(N), size=I0, replace=False)
    for idx in I_indices:
        G.nodes[idx]['disease_state'] = 'I'
    if (len(G.nodes)>= 1000):
        pos = None
    else:
        pos = nx.spring_layout(G)  # Changed from arf_layout
    return G, pos

# %% [markdown]
# ## Network creation

# %%
final_N = 100
I0 = 0
fear_threshold = 0.5
G, pos = graph_setupper(final_N,I0,fear_threshold)
if (len(G.nodes)<1000):
    draw_function(G,None)

# %% [markdown]
# # SIR implementation
# Now we implement the SIR dynamics. In the first cell we set up the constants (that may vary based on nodes age class) and the initial condition of the network. Initial infected nodes are selected randomly.

# %% [markdown]
# ## Parameter Setup and save files

# %%
#########################################
############## PARAMETERS ###############
#########################################
delta = 100          # exponent multiply factor in S -> Sf spontaneous transition

beta = {'A':0.004,
        'E':0.002,
        'Y':0.006} # transmission rate

r_beta = {'A':0.,
        'E':0.,
        'Y':0.} # beta rescaling factor based on age class

mu_f = {'A':0.02,
        'E':0.013,
        'Y':0.012} ### transition Sf+S->2S or Sf + R -> S+R

mu_fear_dist = {'A':0.12,  # mean of the gaussian to sample from in S-> Sf spontaneous trans
                'E':0.08,
                'Y':0.1}  # S-> Sf spontaneous trans 

sigma_fear_dist = 0.05    # std of the gaussian to sample from in S-> Sf spontaneous trans

alpha= {'A':80.,
        'E':75.,
        'Y':100.}  # Sf + S -> 2 Sf 

gammaIR = {'A':0.01,
           'E':0.008,
           'Y':0.03}
###############################
###############################
###############################

param_string = f'{len(G.nodes)}_{I0}_{fear_threshold}_{delta}_{beta["A"]}_{beta["E"]}_{beta["Y"]}_{r_beta["A"]}_{r_beta["E"]}_' + \
               f'{r_beta["Y"]}_{gammaIR["A"]}_{gammaIR["E"]}_{gammaIR["Y"]}_' + \
               f'{mu_f["A"]}_{mu_f["E"]}_{mu_f["Y"]}_' + \
               f'{mu_fear_dist["A"]}_{mu_fear_dist["E"]}_{mu_fear_dist["Y"]}_{sigma_fear_dist}_' + \
               f'{alpha["A"]}_{alpha["E"]}_{alpha["Y"]}'

print("Number of initial Infected: ", sum(G.nodes[n]['disease_state'] == 'I' for n in G.nodes))
        
# make a dir for saving everything related to this
folder_path = f'SIR/{param_string}'
os.makedirs(folder_path,exist_ok = True)

# write out all parameters
'''with open(run_path+f"/run_{run_idx}_parameters.txt","w") as text_file:
    print(f"Parameters by class A, E, Y",file = text_file)
    print(f"beta: {beta['A']} {beta['E']} {beta['Y']}",file = text_file)
    print(f"r_beta: {r_beta['A']} {r_beta['E']} {r_beta['Y']}",file = text_file)
    print(f"gammaIR: {gammaIR['A']} {gammaIR['E']} {gammaIR['Y']}",file = text_file)
    print(f"gammaIR_resc: {gammaIR_resc['A']} {gammaIR_resc['E']} {gammaIR_resc['Y']}",file = text_file)
    print(f"mu_f: {mu_f['A']} {mu_f['E']} {mu_f['Y']}",file = text_file)
    print(f"mu_fear_dist: {mu_fear_dist['A']} {mu_fear_dist['E']} {mu_fear_dist['Y']}",file = text_file)
    print(f"sigma_fear_dist: {sigma_fear_dist}",file = text_file)
    print(f"alpha: {alpha['A']} {alpha['E']} {alpha['Y']}",file = text_file)
'''
# draw the network if it's all ok
path_save_plot = folder_path+f'/initial_cond.png'
if (len(G.nodes)<1000):    
    draw_function(G,path_save_plot)
# Out:
# Number of initial Infected:  12

# %% [markdown]
# ## Degree distribution

# %%
degrees = [d for n, d in G.degree()]

nbins = 30
bins = np.linspace(np.min(degrees),np.max(degrees),nbins)
counts, bins, _ = plt.hist(degrees, bins = bins)
plt.close()
plt.plot(bins[1:],counts)
plt.yscale('log')
plt.xscale('log')
plt.xlabel('degree')
plt.ylabel('freq')
plt.show()

# %% [markdown]
# # CUSTOM SIR

# %%
def custom_SIR_with_fear(G, beta, gammaIR, r_beta, mu_f, alpha,
                              delta, mu_fear_dist, sigma_fear_dist,
                              fear_threshold, tmax,modulo):

    nodes = list(G.nodes())
    neighbors = {n: list(G.neighbors(n)) for n in nodes}
    age = nx.get_node_attributes(G, 'age_class')

    status = {n: G.nodes[n]['disease_state'] for n in nodes}
    statuses = []
    fears = []
    fear   = {n: G.nodes[n]['fear'] for n in nodes}

    Ipop = sum(s == 'I' for s in status.values())
    Rpop = sum(s == 'R' for s in status.values())
    Ntot = len(nodes)

    t = 0.0
    times = []
    event_types = []
    event_counter = 0

    #pbar = tqdm(total=10000*modulo, desc="Gillespie events", unit="event")

    while Ipop > 0 and len(times)<tmax*modulo:

        events = []
        rates = []

        # --- spontaneous events ---
        for n in nodes:
            a = age[n]

            if status[n] == 'I':
                events.append(('IR', n))
                rates.append(gammaIR[a])

            elif status[n] == 'S':
                r = beta[a] * (1 - np.exp(-delta * Ipop / Ntot)) #* r_beta[a]
                if r > 0:
                    events.append(('fear', n))
                    rates.append(r)

            elif status[n] == 'Sf' and Ipop / Npop < Ntot/100:
                r = beta[a] * (1 - np.exp(-delta * 5 * Rpop / Ntot))  # * r_beta[a]
                if r > 0:
                    events.append(('fear_boredom', n))
                    rates.append(r)

        # --- compressed transmission events ---
        for i in nodes:
            if status[i] == 'I':
                a = age[i]
                neigh = neighbors[i]
    
                S_neigh  = [j for j in neigh if status[j] == 'S']
                Sf_neigh = [j for j in neigh if status[j] == 'Sf']
    
                if S_neigh:
                    # S + I → I + I
                    events.append(('SI', (i, S_neigh)))
                    rates.append(len(S_neigh) * beta[a])
    
                    # S + I → Sf + I
                    events.append(('SI_fear', (i, S_neigh)))
                    rates.append(len(S_neigh) * alpha[a] * beta[a])
                    
                    # Sf + I -> 2I
                if Sf_neigh:
                    events.append(('SfI', (i, Sf_neigh)))
                    rates.append(len(Sf_neigh) * beta[a] * r_beta[a])
                    
            elif status[i] == 'R':
                a = age[i]
                neigh = neighbors[i]
    
                Sf_neigh  = [j for j in neigh if status[j] == 'Sf']
            
                if Sf_neigh:
                    # Sf + R -> S + R
                    events.append(('SfR', (i, Sf_neigh)))
                    rates.append(len(Sf_neigh) * mu_f[a])

            elif status[i] == 'S':
                a = age[i]
                neigh = neighbors[i]
    
                Sf_neigh  = [j for j in neigh if status[j] == 'Sf']
            
                if Sf_neigh:
                    # Sf + S -> 2S
                    events.append(('SfS', (i, Sf_neigh)))
                    rates.append(len(Sf_neigh) * mu_f[a])

        total_rate = sum(rates)
        if total_rate == 0:
            break

        # --- Gillespie ---
        dt = np.random.exponential(1 / total_rate)
        t += dt

        idx = np.random.choice(len(events), p=np.array(rates) / total_rate)
        etype, data = events[idx]
        event_types.append(etype)

        # --- execute event ---
        if etype == 'IR':
            n = data
            status[n] = 'R'
            Ipop -= 1
            Rpop += 1

        elif etype == 'fear':
            n = data
            fear[n] = min(1, fear[n] + np.random.normal(mu_fear_dist[age[n]], sigma_fear_dist))
            if fear[n] > fear_threshold:
                status[n] = 'Sf'

        elif etype == 'fear_boredom':
            n = data
            fear[n] = max(0, fear[n] - np.random.normal(2*mu_fear_dist[age[n]], sigma_fear_dist))
            if fear[n] < fear_threshold:
                status[n] = 'S'

        elif etype == 'SI':
            i, Slist = data
            j = np.random.choice(Slist)
            status[j] = 'I'
            Ipop += 1

        elif etype == 'SI_fear':
            i, Slist = data
            j = np.random.choice(Slist)
            fear[j] = min(1, fear[j] + np.random.normal(mu_fear_dist[age[j]], sigma_fear_dist))
            if fear[j] > fear_threshold:
                status[j] = 'Sf'

        elif etype == 'SfI':
            i, Sflist = data
            j = np.random.choice(Sflist)
            status[j] = 'I'
            Ipop += 1
            
        elif etype == 'SfR':
            i, Slist = data
            j = np.random.choice(Slist)
            fear[j] = max(0, fear[j] - np.random.normal(mu_fear_dist[age[j]], sigma_fear_dist))
            if fear[j] < fear_threshold:
                status[j] = 'S'

        elif etype == 'SfS':
            i, Slist = data
            j = np.random.choice(Slist)
            fear[j] = max(0, fear[j] + np.random.normal(mu_fear_dist[age[j]]*0.1,sigma_fear_dist))    # S with Sf can both have increment and decrement of fear
            if fear[j] < fear_threshold:
               status[j] = 'S'

        event_counter += 1
        #pbar.update(1)
        
        if event_counter % modulo== 0:
            times.append(t)
            statuses.append(status.copy())
            fears.append(fear.copy())
            event_types.append(etype)
            print(f'Current I pop: {Ipop}, Current R pop: {Rpop}, Saved events: {len(statuses)}, Seen events: {event_counter}, curr avg fear: {round(np.mean(np.array([f for f in fear.values()])),2)}')
        #if len(times) % modulo == 0:
        #    pbar.set_postfix(time=f"{t:.2f}", I=Ipop)
            
         
    return times, statuses, fears, event_types

# %%
tmax = 50
modulo = 200
t, data,fears,event_types = custom_SIR_with_fear(G, beta, gammaIR, r_beta, mu_f, alpha,delta, mu_fear_dist, sigma_fear_dist,fear_threshold,tmax,modulo)
# Out:
# Current I pop: 12, Current R pop: 0, Saved events: 1, Seen events: 200, curr avg fear: 0.19
# Current I pop: 12, Current R pop: 0, Saved events: 2, Seen events: 400, curr avg fear: 0.2
# Current I pop: 12, Current R pop: 0, Saved events: 3, Seen events: 600, curr avg fear: 0.2
# Current I pop: 13, Current R pop: 0, Saved events: 4, Seen events: 800, curr avg fear: 0.2
# Current I pop: 12, Current R pop: 1, Saved events: 5, Seen events: 1000, curr avg fear: 0.2
# Current I pop: 12, Current R pop: 1, Saved events: 6, Seen events: 1200, curr avg fear: 0.21
# Current I pop: 13, Current R pop: 1, Saved events: 7, Seen events: 1400, curr avg fear: 0.21
# Current I pop: 13, Current R pop: 1, Saved events: 8, Seen events: 1600, curr avg fear: 0.21
# Current I pop: 14, Current R pop: 1, Saved events: 9, Seen events: 1800, curr avg fear: 0.21
# Current I pop: 14, Current R pop: 1, Saved events: 10, Seen events: 2000, curr avg fear: 0.21
# Current I pop: 14, Current R pop: 1, Saved events: 11, Seen events: 2200, curr avg fear: 0.22
# Current I pop: 13, Current R pop: 2, Saved events: 12, Seen events: 2400, curr avg fear: 0.22
# Current I pop: 14, Current R pop: 2, Saved events: 13, Seen events: 2600, curr avg fear: 0.22
# Current I pop: 16, Current R pop: 2, Saved events: 14, Seen events: 2800, curr avg fear: 0.22
# Current I pop: 16, Current R pop: 2, Saved events: 15, Seen events: 3000, curr avg fear: 0.22
# Current I pop: 16, Current R pop: 3, Saved events: 16, Seen events: 3200, curr avg fear: 0.22
# Current I pop: 17, Current R pop: 3, Saved events: 17, Seen events: 3400, curr avg fear: 0.23
# Current I pop: 17, Current R pop: 3, Saved events: 18, Seen events: 3600, curr avg fear: 0.23
# Current I pop: 17, Current R pop: 3, Saved events: 19, Seen events: 3800, curr avg fear: 0.23
# Current I pop: 18, Current R pop: 3, Saved events: 20, Seen events: 4000, curr avg fear: 0.24
# Current I pop: 20, Current R pop: 3, Saved events: 21, Seen events: 4200, curr avg fear: 0.24
# Current I pop: 23, Current R pop: 3, Saved events: 22, Seen events: 4400, curr avg fear: 0.24
# Current I pop: 24, Current R pop: 3, Saved events: 23, Seen events: 4600, curr avg fear: 0.24
# Current I pop: 24, Current R pop: 3, Saved events: 24, Seen events: 4800, curr avg fear: 0.25
# Current I pop: 25, Current R pop: 3, Saved events: 25, Seen events: 5000, curr avg fear: 0.25
# Current I pop: 26, Current R pop: 3, Saved events: 26, Seen events: 5200, curr avg fear: 0.25
# Current I pop: 26, Current R pop: 3, Saved events: 27, Seen events: 5400, curr avg fear: 0.26
# Current I pop: 26, Current R pop: 3, Saved events: 28, Seen events: 5600, curr avg fear: 0.26
# Current I pop: 26, Current R pop: 3, Saved events: 29, Seen events: 5800, curr avg fear: 0.26
# Current I pop: 28, Current R pop: 3, Saved events: 30, Seen events: 6000, curr avg fear: 0.26
# Current I pop: 30, Current R pop: 3, Saved events: 31, Seen events: 6200, curr avg fear: 0.27
# Current I pop: 30, Current R pop: 3, Saved events: 32, Seen events: 6400, curr avg fear: 0.27
# Current I pop: 29, Current R pop: 4, Saved events: 33, Seen events: 6600, curr avg fear: 0.27
# Current I pop: 29, Current R pop: 4, Saved events: 34, Seen events: 6800, curr avg fear: 0.27
# Current I pop: 29, Current R pop: 4, Saved events: 35, Seen events: 7000, curr avg fear: 0.28
# Current I pop: 29, Current R pop: 4, Saved events: 36, Seen events: 7200, curr avg fear: 0.28
# Current I pop: 29, Current R pop: 4, Saved events: 37, Seen events: 7400, curr avg fear: 0.28
# Current I pop: 29, Current R pop: 4, Saved events: 38, Seen events: 7600, curr avg fear: 0.28
# Current I pop: 30, Current R pop: 4, Saved events: 39, Seen events: 7800, curr avg fear: 0.28
# Current I pop: 30, Current R pop: 4, Saved events: 40, Seen events: 8000, curr avg fear: 0.29
# Current I pop: 31, Current R pop: 4, Saved events: 41, Seen events: 8200, curr avg fear: 0.29
# Current I pop: 36, Current R pop: 4, Saved events: 42, Seen events: 8400, curr avg fear: 0.29
# Current I pop: 36, Current R pop: 4, Saved events: 43, Seen events: 8600, curr avg fear: 0.29
# Current I pop: 36, Current R pop: 4, Saved events: 44, Seen events: 8800, curr avg fear: 0.29
# Current I pop: 35, Current R pop: 5, Saved events: 45, Seen events: 9000, curr avg fear: 0.3
# Current I pop: 36, Current R pop: 5, Saved events: 46, Seen events: 9200, curr avg fear: 0.3
# Current I pop: 35, Current R pop: 6, Saved events: 47, Seen events: 9400, curr avg fear: 0.3
# Current I pop: 37, Current R pop: 6, Saved events: 48, Seen events: 9600, curr avg fear: 0.3
# Current I pop: 38, Current R pop: 6, Saved events: 49, Seen events: 9800, curr avg fear: 0.31
# Current I pop: 39, Current R pop: 6, Saved events: 50, Seen events: 10000, curr avg fear: 0.31
# Current I pop: 40, Current R pop: 6, Saved events: 51, Seen events: 10200, curr avg fear: 0.31
# Current I pop: 40, Current R pop: 6, Saved events: 52, Seen events: 10400, curr avg fear: 0.31
# Current I pop: 40, Current R pop: 6, Saved events: 53, Seen events: 10600, curr avg fear: 0.32
# Current I pop: 41, Current R pop: 6, Saved events: 54, Seen events: 10800, curr avg fear: 0.32
# Current I pop: 41, Current R pop: 6, Saved events: 55, Seen events: 11000, curr avg fear: 0.32
# Current I pop: 42, Current R pop: 6, Saved events: 56, Seen events: 11200, curr avg fear: 0.32
# Current I pop: 45, Current R pop: 6, Saved events: 57, Seen events: 11400, curr avg fear: 0.33
# Current I pop: 46, Current R pop: 6, Saved events: 58, Seen events: 11600, curr avg fear: 0.33
# Current I pop: 47, Current R pop: 6, Saved events: 59, Seen events: 11800, curr avg fear: 0.33
# Current I pop: 47, Current R pop: 6, Saved events: 60, Seen events: 12000, curr avg fear: 0.33
# Current I pop: 48, Current R pop: 6, Saved events: 61, Seen events: 12200, curr avg fear: 0.33
# Current I pop: 48, Current R pop: 6, Saved events: 62, Seen events: 12400, curr avg fear: 0.34
# Current I pop: 48, Current R pop: 6, Saved events: 63, Seen events: 12600, curr avg fear: 0.34
# Current I pop: 49, Current R pop: 6, Saved events: 64, Seen events: 12800, curr avg fear: 0.34
# Current I pop: 49, Current R pop: 6, Saved events: 65, Seen events: 13000, curr avg fear: 0.34
# Current I pop: 50, Current R pop: 6, Saved events: 66, Seen events: 13200, curr avg fear: 0.34
# Current I pop: 50, Current R pop: 6, Saved events: 67, Seen events: 13400, curr avg fear: 0.34
# Current I pop: 51, Current R pop: 6, Saved events: 68, Seen events: 13600, curr avg fear: 0.34
# Current I pop: 52, Current R pop: 6, Saved events: 69, Seen events: 13800, curr avg fear: 0.35
# Current I pop: 52, Current R pop: 6, Saved events: 70, Seen events: 14000, curr avg fear: 0.35
# Current I pop: 52, Current R pop: 6, Saved events: 71, Seen events: 14200, curr avg fear: 0.35
# Current I pop: 53, Current R pop: 6, Saved events: 72, Seen events: 14400, curr avg fear: 0.35
# Current I pop: 53, Current R pop: 6, Saved events: 73, Seen events: 14600, curr avg fear: 0.35
# Current I pop: 53, Current R pop: 6, Saved events: 74, Seen events: 14800, curr avg fear: 0.35
# Current I pop: 52, Current R pop: 7, Saved events: 75, Seen events: 15000, curr avg fear: 0.35
# Current I pop: 53, Current R pop: 7, Saved events: 76, Seen events: 15200, curr avg fear: 0.35
# Current I pop: 54, Current R pop: 7, Saved events: 77, Seen events: 15400, curr avg fear: 0.36
# Current I pop: 55, Current R pop: 7, Saved events: 78, Seen events: 15600, curr avg fear: 0.36
# Current I pop: 55, Current R pop: 7, Saved events: 79, Seen events: 15800, curr avg fear: 0.36
# Current I pop: 56, Current R pop: 7, Saved events: 80, Seen events: 16000, curr avg fear: 0.36
# Current I pop: 56, Current R pop: 7, Saved events: 81, Seen events: 16200, curr avg fear: 0.36
# Current I pop: 57, Current R pop: 7, Saved events: 82, Seen events: 16400, curr avg fear: 0.36
# Current I pop: 57, Current R pop: 7, Saved events: 83, Seen events: 16600, curr avg fear: 0.36
# Current I pop: 57, Current R pop: 7, Saved events: 84, Seen events: 16800, curr avg fear: 0.37
# Current I pop: 57, Current R pop: 7, Saved events: 85, Seen events: 17000, curr avg fear: 0.37
# Current I pop: 57, Current R pop: 7, Saved events: 86, Seen events: 17200, curr avg fear: 0.37
# Current I pop: 58, Current R pop: 7, Saved events: 87, Seen events: 17400, curr avg fear: 0.37
# Current I pop: 58, Current R pop: 7, Saved events: 88, Seen events: 17600, curr avg fear: 0.37
# Current I pop: 57, Current R pop: 8, Saved events: 89, Seen events: 17800, curr avg fear: 0.37
# Current I pop: 58, Current R pop: 8, Saved events: 90, Seen events: 18000, curr avg fear: 0.37
# Current I pop: 58, Current R pop: 8, Saved events: 91, Seen events: 18200, curr avg fear: 0.38
# Current I pop: 58, Current R pop: 8, Saved events: 92, Seen events: 18400, curr avg fear: 0.38
# Current I pop: 58, Current R pop: 8, Saved events: 93, Seen events: 18600, curr avg fear: 0.38
# Current I pop: 59, Current R pop: 8, Saved events: 94, Seen events: 18800, curr avg fear: 0.38
# Current I pop: 58, Current R pop: 9, Saved events: 95, Seen events: 19000, curr avg fear: 0.38
# Current I pop: 57, Current R pop: 10, Saved events: 96, Seen events: 19200, curr avg fear: 0.38
# Current I pop: 57, Current R pop: 10, Saved events: 97, Seen events: 19400, curr avg fear: 0.38
# Current I pop: 56, Current R pop: 11, Saved events: 98, Seen events: 19600, curr avg fear: 0.38
# Current I pop: 57, Current R pop: 11, Saved events: 99, Seen events: 19800, curr avg fear: 0.39
# Current I pop: 58, Current R pop: 12, Saved events: 100, Seen events: 20000, curr avg fear: 0.39
# Current I pop: 58, Current R pop: 12, Saved events: 101, Seen events: 20200, curr avg fear: 0.39
# Current I pop: 57, Current R pop: 13, Saved events: 102, Seen events: 20400, curr avg fear: 0.39
# Current I pop: 57, Current R pop: 13, Saved events: 103, Seen events: 20600, curr avg fear: 0.39
# Current I pop: 57, Current R pop: 13, Saved events: 104, Seen events: 20800, curr avg fear: 0.39
# Current I pop: 57, Current R pop: 13, Saved events: 105, Seen events: 21000, curr avg fear: 0.39
# Current I pop: 57, Current R pop: 13, Saved events: 106, Seen events: 21200, curr avg fear: 0.39
# Current I pop: 58, Current R pop: 13, Saved events: 107, Seen events: 21400, curr avg fear: 0.39
# Current I pop: 58, Current R pop: 13, Saved events: 108, Seen events: 21600, curr avg fear: 0.39
# Current I pop: 58, Current R pop: 13, Saved events: 109, Seen events: 21800, curr avg fear: 0.39
# Current I pop: 59, Current R pop: 13, Saved events: 110, Seen events: 22000, curr avg fear: 0.39
# Current I pop: 59, Current R pop: 13, Saved events: 111, Seen events: 22200, curr avg fear: 0.39
# Current I pop: 59, Current R pop: 13, Saved events: 112, Seen events: 22400, curr avg fear: 0.4
# Current I pop: 58, Current R pop: 14, Saved events: 113, Seen events: 22600, curr avg fear: 0.4
# Current I pop: 58, Current R pop: 14, Saved events: 114, Seen events: 22800, curr avg fear: 0.4
# Current I pop: 59, Current R pop: 14, Saved events: 115, Seen events: 23000, curr avg fear: 0.4
# Current I pop: 58, Current R pop: 15, Saved events: 116, Seen events: 23200, curr avg fear: 0.4
# Current I pop: 58, Current R pop: 15, Saved events: 117, Seen events: 23400, curr avg fear: 0.4
# Current I pop: 58, Current R pop: 15, Saved events: 118, Seen events: 23600, curr avg fear: 0.4
# Current I pop: 56, Current R pop: 17, Saved events: 119, Seen events: 23800, curr avg fear: 0.4
# Current I pop: 56, Current R pop: 17, Saved events: 120, Seen events: 24000, curr avg fear: 0.4
# Current I pop: 56, Current R pop: 17, Saved events: 121, Seen events: 24200, curr avg fear: 0.4
# Current I pop: 57, Current R pop: 17, Saved events: 122, Seen events: 24400, curr avg fear: 0.4
# Current I pop: 56, Current R pop: 18, Saved events: 123, Seen events: 24600, curr avg fear: 0.4
# Current I pop: 57, Current R pop: 18, Saved events: 124, Seen events: 24800, curr avg fear: 0.41
# Current I pop: 57, Current R pop: 18, Saved events: 125, Seen events: 25000, curr avg fear: 0.41
# Current I pop: 57, Current R pop: 18, Saved events: 126, Seen events: 25200, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 19, Saved events: 127, Seen events: 25400, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 19, Saved events: 128, Seen events: 25600, curr avg fear: 0.41
# Current I pop: 54, Current R pop: 21, Saved events: 129, Seen events: 25800, curr avg fear: 0.41
# Current I pop: 55, Current R pop: 21, Saved events: 130, Seen events: 26000, curr avg fear: 0.41
# Current I pop: 55, Current R pop: 21, Saved events: 131, Seen events: 26200, curr avg fear: 0.41
# Current I pop: 55, Current R pop: 21, Saved events: 132, Seen events: 26400, curr avg fear: 0.41
# Current I pop: 55, Current R pop: 21, Saved events: 133, Seen events: 26600, curr avg fear: 0.41
# Current I pop: 55, Current R pop: 21, Saved events: 134, Seen events: 26800, curr avg fear: 0.41
# Current I pop: 55, Current R pop: 21, Saved events: 135, Seen events: 27000, curr avg fear: 0.41
# Current I pop: 55, Current R pop: 21, Saved events: 136, Seen events: 27200, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 21, Saved events: 137, Seen events: 27400, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 21, Saved events: 138, Seen events: 27600, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 21, Saved events: 139, Seen events: 27800, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 21, Saved events: 140, Seen events: 28000, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 21, Saved events: 141, Seen events: 28200, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 21, Saved events: 142, Seen events: 28400, curr avg fear: 0.41
# Current I pop: 56, Current R pop: 21, Saved events: 143, Seen events: 28600, curr avg fear: 0.42
# Current I pop: 56, Current R pop: 21, Saved events: 144, Seen events: 28800, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 22, Saved events: 145, Seen events: 29000, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 22, Saved events: 146, Seen events: 29200, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 22, Saved events: 147, Seen events: 29400, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 22, Saved events: 148, Seen events: 29600, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 22, Saved events: 149, Seen events: 29800, curr avg fear: 0.42
# Current I pop: 56, Current R pop: 22, Saved events: 150, Seen events: 30000, curr avg fear: 0.42
# Current I pop: 56, Current R pop: 22, Saved events: 151, Seen events: 30200, curr avg fear: 0.42
# Current I pop: 56, Current R pop: 22, Saved events: 152, Seen events: 30400, curr avg fear: 0.42
# Current I pop: 56, Current R pop: 22, Saved events: 153, Seen events: 30600, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 23, Saved events: 154, Seen events: 30800, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 23, Saved events: 155, Seen events: 31000, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 23, Saved events: 156, Seen events: 31200, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 23, Saved events: 157, Seen events: 31400, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 23, Saved events: 158, Seen events: 31600, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 23, Saved events: 159, Seen events: 31800, curr avg fear: 0.42
# Current I pop: 55, Current R pop: 23, Saved events: 160, Seen events: 32000, curr avg fear: 0.42
# Current I pop: 54, Current R pop: 24, Saved events: 161, Seen events: 32200, curr avg fear: 0.42
# Current I pop: 54, Current R pop: 24, Saved events: 162, Seen events: 32400, curr avg fear: 0.42
# Current I pop: 54, Current R pop: 24, Saved events: 163, Seen events: 32600, curr avg fear: 0.42
# Current I pop: 54, Current R pop: 24, Saved events: 164, Seen events: 32800, curr avg fear: 0.42
# Current I pop: 53, Current R pop: 25, Saved events: 165, Seen events: 33000, curr avg fear: 0.42
# Current I pop: 53, Current R pop: 25, Saved events: 166, Seen events: 33200, curr avg fear: 0.42
# Current I pop: 53, Current R pop: 26, Saved events: 167, Seen events: 33400, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 26, Saved events: 168, Seen events: 33600, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 26, Saved events: 169, Seen events: 33800, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 26, Saved events: 170, Seen events: 34000, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 26, Saved events: 171, Seen events: 34200, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 26, Saved events: 172, Seen events: 34400, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 26, Saved events: 173, Seen events: 34600, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 26, Saved events: 174, Seen events: 34800, curr avg fear: 0.43
# Current I pop: 52, Current R pop: 27, Saved events: 175, Seen events: 35000, curr avg fear: 0.43
# Current I pop: 52, Current R pop: 27, Saved events: 176, Seen events: 35200, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 27, Saved events: 177, Seen events: 35400, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 27, Saved events: 178, Seen events: 35600, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 27, Saved events: 179, Seen events: 35800, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 27, Saved events: 180, Seen events: 36000, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 27, Saved events: 181, Seen events: 36200, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 27, Saved events: 182, Seen events: 36400, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 27, Saved events: 183, Seen events: 36600, curr avg fear: 0.43
# Current I pop: 53, Current R pop: 27, Saved events: 184, Seen events: 36800, curr avg fear: 0.44
# Current I pop: 53, Current R pop: 27, Saved events: 185, Seen events: 37000, curr avg fear: 0.44
# Current I pop: 53, Current R pop: 27, Saved events: 186, Seen events: 37200, curr avg fear: 0.44
# Current I pop: 53, Current R pop: 27, Saved events: 187, Seen events: 37400, curr avg fear: 0.44
# Current I pop: 53, Current R pop: 27, Saved events: 188, Seen events: 37600, curr avg fear: 0.44
# Current I pop: 53, Current R pop: 27, Saved events: 189, Seen events: 37800, curr avg fear: 0.44
# Current I pop: 53, Current R pop: 27, Saved events: 190, Seen events: 38000, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 27, Saved events: 191, Seen events: 38200, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 27, Saved events: 192, Seen events: 38400, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 27, Saved events: 193, Seen events: 38600, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 27, Saved events: 194, Seen events: 38800, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 27, Saved events: 195, Seen events: 39000, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 27, Saved events: 196, Seen events: 39200, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 27, Saved events: 197, Seen events: 39400, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 27, Saved events: 198, Seen events: 39600, curr avg fear: 0.44
# Current I pop: 55, Current R pop: 27, Saved events: 199, Seen events: 39800, curr avg fear: 0.44
# Current I pop: 54, Current R pop: 28, Saved events: 200, Seen events: 40000, curr avg fear: 0.44
# Current I pop: 55, Current R pop: 28, Saved events: 201, Seen events: 40200, curr avg fear: 0.44
# Current I pop: 55, Current R pop: 28, Saved events: 202, Seen events: 40400, curr avg fear: 0.44
# Current I pop: 55, Current R pop: 28, Saved events: 203, Seen events: 40600, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 204, Seen events: 40800, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 205, Seen events: 41000, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 206, Seen events: 41200, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 207, Seen events: 41400, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 208, Seen events: 41600, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 209, Seen events: 41800, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 210, Seen events: 42000, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 211, Seen events: 42200, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 212, Seen events: 42400, curr avg fear: 0.45
# Current I pop: 55, Current R pop: 28, Saved events: 213, Seen events: 42600, curr avg fear: 0.45
# Current I pop: 53, Current R pop: 30, Saved events: 214, Seen events: 42800, curr avg fear: 0.45
# Current I pop: 52, Current R pop: 31, Saved events: 215, Seen events: 43000, curr avg fear: 0.45
# Current I pop: 52, Current R pop: 31, Saved events: 216, Seen events: 43200, curr avg fear: 0.45
# Current I pop: 52, Current R pop: 31, Saved events: 217, Seen events: 43400, curr avg fear: 0.45
# Current I pop: 52, Current R pop: 31, Saved events: 218, Seen events: 43600, curr avg fear: 0.45
# Current I pop: 52, Current R pop: 31, Saved events: 219, Seen events: 43800, curr avg fear: 0.45
# Current I pop: 53, Current R pop: 31, Saved events: 220, Seen events: 44000, curr avg fear: 0.45
# Current I pop: 53, Current R pop: 31, Saved events: 221, Seen events: 44200, curr avg fear: 0.45
# Current I pop: 53, Current R pop: 31, Saved events: 222, Seen events: 44400, curr avg fear: 0.45
# Current I pop: 52, Current R pop: 32, Saved events: 223, Seen events: 44600, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 224, Seen events: 44800, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 225, Seen events: 45000, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 226, Seen events: 45200, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 227, Seen events: 45400, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 228, Seen events: 45600, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 229, Seen events: 45800, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 230, Seen events: 46000, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 231, Seen events: 46200, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 232, Seen events: 46400, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 32, Saved events: 233, Seen events: 46600, curr avg fear: 0.46
# Current I pop: 51, Current R pop: 33, Saved events: 234, Seen events: 46800, curr avg fear: 0.46
# Current I pop: 51, Current R pop: 33, Saved events: 235, Seen events: 47000, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 236, Seen events: 47200, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 237, Seen events: 47400, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 238, Seen events: 47600, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 239, Seen events: 47800, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 240, Seen events: 48000, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 241, Seen events: 48200, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 242, Seen events: 48400, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 243, Seen events: 48600, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 244, Seen events: 48800, curr avg fear: 0.46
# Current I pop: 52, Current R pop: 33, Saved events: 245, Seen events: 49000, curr avg fear: 0.46
# Current I pop: 53, Current R pop: 33, Saved events: 246, Seen events: 49200, curr avg fear: 0.46
# Current I pop: 53, Current R pop: 33, Saved events: 247, Seen events: 49400, curr avg fear: 0.47
# Current I pop: 53, Current R pop: 33, Saved events: 248, Seen events: 49600, curr avg fear: 0.47
# Current I pop: 53, Current R pop: 33, Saved events: 249, Seen events: 49800, curr avg fear: 0.47
# Current I pop: 53, Current R pop: 33, Saved events: 250, Seen events: 50000, curr avg fear: 0.47
# Current I pop: 53, Current R pop: 33, Saved events: 251, Seen events: 50200, curr avg fear: 0.47
# Current I pop: 53, Current R pop: 33, Saved events: 252, Seen events: 50400, curr avg fear: 0.47
# Current I pop: 52, Current R pop: 34, Saved events: 253, Seen events: 50600, curr avg fear: 0.47
# Current I pop: 51, Current R pop: 35, Saved events: 254, Seen events: 50800, curr avg fear: 0.47
# Current I pop: 51, Current R pop: 35, Saved events: 255, Seen events: 51000, curr avg fear: 0.47
# Current I pop: 51, Current R pop: 35, Saved events: 256, Seen events: 51200, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 36, Saved events: 257, Seen events: 51400, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 36, Saved events: 258, Seen events: 51600, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 36, Saved events: 259, Seen events: 51800, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 36, Saved events: 260, Seen events: 52000, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 36, Saved events: 261, Seen events: 52200, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 36, Saved events: 262, Seen events: 52400, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 36, Saved events: 263, Seen events: 52600, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 36, Saved events: 264, Seen events: 52800, curr avg fear: 0.47
# Current I pop: 49, Current R pop: 37, Saved events: 265, Seen events: 53000, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 37, Saved events: 266, Seen events: 53200, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 37, Saved events: 267, Seen events: 53400, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 37, Saved events: 268, Seen events: 53600, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 37, Saved events: 269, Seen events: 53800, curr avg fear: 0.47
# Current I pop: 50, Current R pop: 37, Saved events: 270, Seen events: 54000, curr avg fear: 0.47
# Current I pop: 51, Current R pop: 37, Saved events: 271, Seen events: 54200, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 38, Saved events: 272, Seen events: 54400, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 38, Saved events: 273, Seen events: 54600, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 38, Saved events: 274, Seen events: 54800, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 38, Saved events: 275, Seen events: 55000, curr avg fear: 0.48
# Current I pop: 51, Current R pop: 38, Saved events: 276, Seen events: 55200, curr avg fear: 0.48
# Current I pop: 51, Current R pop: 38, Saved events: 277, Seen events: 55400, curr avg fear: 0.48
# Current I pop: 51, Current R pop: 38, Saved events: 278, Seen events: 55600, curr avg fear: 0.48
# Current I pop: 51, Current R pop: 38, Saved events: 279, Seen events: 55800, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 280, Seen events: 56000, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 281, Seen events: 56200, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 282, Seen events: 56400, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 283, Seen events: 56600, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 284, Seen events: 56800, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 285, Seen events: 57000, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 286, Seen events: 57200, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 287, Seen events: 57400, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 288, Seen events: 57600, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 289, Seen events: 57800, curr avg fear: 0.48
# Current I pop: 50, Current R pop: 39, Saved events: 290, Seen events: 58000, curr avg fear: 0.48
# Current I pop: 49, Current R pop: 40, Saved events: 291, Seen events: 58200, curr avg fear: 0.48
# Current I pop: 49, Current R pop: 40, Saved events: 292, Seen events: 58400, curr avg fear: 0.48
# Current I pop: 49, Current R pop: 40, Saved events: 293, Seen events: 58600, curr avg fear: 0.48
# Current I pop: 49, Current R pop: 40, Saved events: 294, Seen events: 58800, curr avg fear: 0.48
# Current I pop: 48, Current R pop: 41, Saved events: 295, Seen events: 59000, curr avg fear: 0.48
# Current I pop: 48, Current R pop: 41, Saved events: 296, Seen events: 59200, curr avg fear: 0.48
# Current I pop: 48, Current R pop: 41, Saved events: 297, Seen events: 59400, curr avg fear: 0.48
# Current I pop: 48, Current R pop: 41, Saved events: 298, Seen events: 59600, curr avg fear: 0.48
# Current I pop: 48, Current R pop: 41, Saved events: 299, Seen events: 59800, curr avg fear: 0.49
# Current I pop: 48, Current R pop: 41, Saved events: 300, Seen events: 60000, curr avg fear: 0.49
# Current I pop: 48, Current R pop: 41, Saved events: 301, Seen events: 60200, curr avg fear: 0.49
# Current I pop: 48, Current R pop: 41, Saved events: 302, Seen events: 60400, curr avg fear: 0.49
# Current I pop: 48, Current R pop: 41, Saved events: 303, Seen events: 60600, curr avg fear: 0.49
# Current I pop: 48, Current R pop: 41, Saved events: 304, Seen events: 60800, curr avg fear: 0.49
# Current I pop: 48, Current R pop: 41, Saved events: 305, Seen events: 61000, curr avg fear: 0.49
# Current I pop: 48, Current R pop: 41, Saved events: 306, Seen events: 61200, curr avg fear: 0.49
# Current I pop: 49, Current R pop: 41, Saved events: 307, Seen events: 61400, curr avg fear: 0.49
# Current I pop: 49, Current R pop: 41, Saved events: 308, Seen events: 61600, curr avg fear: 0.49
# Current I pop: 50, Current R pop: 42, Saved events: 309, Seen events: 61800, curr avg fear: 0.49
# Current I pop: 50, Current R pop: 42, Saved events: 310, Seen events: 62000, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 42, Saved events: 311, Seen events: 62200, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 42, Saved events: 312, Seen events: 62400, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 43, Saved events: 313, Seen events: 62600, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 43, Saved events: 314, Seen events: 62800, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 43, Saved events: 315, Seen events: 63000, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 43, Saved events: 316, Seen events: 63200, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 44, Saved events: 317, Seen events: 63400, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 44, Saved events: 318, Seen events: 63600, curr avg fear: 0.49
# Current I pop: 51, Current R pop: 44, Saved events: 319, Seen events: 63800, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 44, Saved events: 320, Seen events: 64000, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 44, Saved events: 321, Seen events: 64200, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 44, Saved events: 322, Seen events: 64400, curr avg fear: 0.5
# Current I pop: 50, Current R pop: 45, Saved events: 323, Seen events: 64600, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 45, Saved events: 324, Seen events: 64800, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 45, Saved events: 325, Seen events: 65000, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 45, Saved events: 326, Seen events: 65200, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 45, Saved events: 327, Seen events: 65400, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 45, Saved events: 328, Seen events: 65600, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 45, Saved events: 329, Seen events: 65800, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 46, Saved events: 330, Seen events: 66000, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 46, Saved events: 331, Seen events: 66200, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 46, Saved events: 332, Seen events: 66400, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 46, Saved events: 333, Seen events: 66600, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 46, Saved events: 334, Seen events: 66800, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 46, Saved events: 335, Seen events: 67000, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 46, Saved events: 336, Seen events: 67200, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 46, Saved events: 337, Seen events: 67400, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 46, Saved events: 338, Seen events: 67600, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 46, Saved events: 339, Seen events: 67800, curr avg fear: 0.5
# Current I pop: 53, Current R pop: 46, Saved events: 340, Seen events: 68000, curr avg fear: 0.5
# Current I pop: 54, Current R pop: 46, Saved events: 341, Seen events: 68200, curr avg fear: 0.5
# Current I pop: 54, Current R pop: 46, Saved events: 342, Seen events: 68400, curr avg fear: 0.5
# Current I pop: 53, Current R pop: 47, Saved events: 343, Seen events: 68600, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 48, Saved events: 344, Seen events: 68800, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 48, Saved events: 345, Seen events: 69000, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 48, Saved events: 346, Seen events: 69200, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 48, Saved events: 347, Seen events: 69400, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 48, Saved events: 348, Seen events: 69600, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 48, Saved events: 349, Seen events: 69800, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 48, Saved events: 350, Seen events: 70000, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 48, Saved events: 351, Seen events: 70200, curr avg fear: 0.5
# Current I pop: 51, Current R pop: 49, Saved events: 352, Seen events: 70400, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 49, Saved events: 353, Seen events: 70600, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 49, Saved events: 354, Seen events: 70800, curr avg fear: 0.5
# Current I pop: 53, Current R pop: 49, Saved events: 355, Seen events: 71000, curr avg fear: 0.5
# Current I pop: 53, Current R pop: 49, Saved events: 356, Seen events: 71200, curr avg fear: 0.5
# Current I pop: 53, Current R pop: 49, Saved events: 357, Seen events: 71400, curr avg fear: 0.5
# Current I pop: 53, Current R pop: 49, Saved events: 358, Seen events: 71600, curr avg fear: 0.5
# Current I pop: 53, Current R pop: 49, Saved events: 359, Seen events: 71800, curr avg fear: 0.5
# Current I pop: 52, Current R pop: 50, Saved events: 360, Seen events: 72000, curr avg fear: 0.5
# Current I pop: 53, Current R pop: 50, Saved events: 361, Seen events: 72200, curr avg fear: 0.51
# Current I pop: 53, Current R pop: 50, Saved events: 362, Seen events: 72400, curr avg fear: 0.51
# Current I pop: 53, Current R pop: 50, Saved events: 363, Seen events: 72600, curr avg fear: 0.51
# Current I pop: 53, Current R pop: 50, Saved events: 364, Seen events: 72800, curr avg fear: 0.51
# Current I pop: 53, Current R pop: 50, Saved events: 365, Seen events: 73000, curr avg fear: 0.51
# Current I pop: 53, Current R pop: 50, Saved events: 366, Seen events: 73200, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 367, Seen events: 73400, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 368, Seen events: 73600, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 369, Seen events: 73800, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 370, Seen events: 74000, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 371, Seen events: 74200, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 372, Seen events: 74400, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 373, Seen events: 74600, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 374, Seen events: 74800, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 375, Seen events: 75000, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 376, Seen events: 75200, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 377, Seen events: 75400, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 378, Seen events: 75600, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 379, Seen events: 75800, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 380, Seen events: 76000, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 381, Seen events: 76200, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 382, Seen events: 76400, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 383, Seen events: 76600, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 384, Seen events: 76800, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 385, Seen events: 77000, curr avg fear: 0.51
# Current I pop: 52, Current R pop: 51, Saved events: 386, Seen events: 77200, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 387, Seen events: 77400, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 388, Seen events: 77600, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 389, Seen events: 77800, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 390, Seen events: 78000, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 391, Seen events: 78200, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 392, Seen events: 78400, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 393, Seen events: 78600, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 394, Seen events: 78800, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 395, Seen events: 79000, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 396, Seen events: 79200, curr avg fear: 0.51
# Current I pop: 51, Current R pop: 52, Saved events: 397, Seen events: 79400, curr avg fear: 0.52
# Current I pop: 51, Current R pop: 52, Saved events: 398, Seen events: 79600, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 399, Seen events: 79800, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 400, Seen events: 80000, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 401, Seen events: 80200, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 402, Seen events: 80400, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 403, Seen events: 80600, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 404, Seen events: 80800, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 405, Seen events: 81000, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 406, Seen events: 81200, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 407, Seen events: 81400, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 408, Seen events: 81600, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 409, Seen events: 81800, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 410, Seen events: 82000, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 411, Seen events: 82200, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 412, Seen events: 82400, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 413, Seen events: 82600, curr avg fear: 0.52
# Current I pop: 52, Current R pop: 52, Saved events: 414, Seen events: 82800, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 415, Seen events: 83000, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 416, Seen events: 83200, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 417, Seen events: 83400, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 418, Seen events: 83600, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 419, Seen events: 83800, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 420, Seen events: 84000, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 421, Seen events: 84200, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 422, Seen events: 84400, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 423, Seen events: 84600, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 424, Seen events: 84800, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 425, Seen events: 85000, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 426, Seen events: 85200, curr avg fear: 0.52
# Current I pop: 53, Current R pop: 52, Saved events: 427, Seen events: 85400, curr avg fear: 0.52
# Current I pop: 54, Current R pop: 52, Saved events: 428, Seen events: 85600, curr avg fear: 0.52
# Current I pop: 54, Current R pop: 52, Saved events: 429, Seen events: 85800, curr avg fear: 0.52
# Current I pop: 54, Current R pop: 52, Saved events: 430, Seen events: 86000, curr avg fear: 0.52
# Current I pop: 54, Current R pop: 52, Saved events: 431, Seen events: 86200, curr avg fear: 0.52
# Current I pop: 55, Current R pop: 52, Saved events: 432, Seen events: 86400, curr avg fear: 0.52
# Current I pop: 54, Current R pop: 53, Saved events: 433, Seen events: 86600, curr avg fear: 0.53
# Current I pop: 54, Current R pop: 53, Saved events: 434, Seen events: 86800, curr avg fear: 0.53
# Current I pop: 54, Current R pop: 53, Saved events: 435, Seen events: 87000, curr avg fear: 0.53
# Current I pop: 54, Current R pop: 53, Saved events: 436, Seen events: 87200, curr avg fear: 0.53
# Current I pop: 54, Current R pop: 53, Saved events: 437, Seen events: 87400, curr avg fear: 0.53
# Current I pop: 54, Current R pop: 53, Saved events: 438, Seen events: 87600, curr avg fear: 0.53
# Current I pop: 54, Current R pop: 53, Saved events: 439, Seen events: 87800, curr avg fear: 0.53
# Current I pop: 55, Current R pop: 53, Saved events: 440, Seen events: 88000, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 441, Seen events: 88200, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 442, Seen events: 88400, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 443, Seen events: 88600, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 444, Seen events: 88800, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 445, Seen events: 89000, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 446, Seen events: 89200, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 447, Seen events: 89400, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 448, Seen events: 89600, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 53, Saved events: 449, Seen events: 89800, curr avg fear: 0.53
# Current I pop: 57, Current R pop: 53, Saved events: 450, Seen events: 90000, curr avg fear: 0.53
# Current I pop: 57, Current R pop: 53, Saved events: 451, Seen events: 90200, curr avg fear: 0.53
# Current I pop: 57, Current R pop: 53, Saved events: 452, Seen events: 90400, curr avg fear: 0.53
# Current I pop: 57, Current R pop: 53, Saved events: 453, Seen events: 90600, curr avg fear: 0.53
# Current I pop: 58, Current R pop: 53, Saved events: 454, Seen events: 90800, curr avg fear: 0.53
# Current I pop: 58, Current R pop: 53, Saved events: 455, Seen events: 91000, curr avg fear: 0.53
# Current I pop: 57, Current R pop: 54, Saved events: 456, Seen events: 91200, curr avg fear: 0.53
# Current I pop: 57, Current R pop: 54, Saved events: 457, Seen events: 91400, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 55, Saved events: 458, Seen events: 91600, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 55, Saved events: 459, Seen events: 91800, curr avg fear: 0.53
# Current I pop: 56, Current R pop: 55, Saved events: 460, Seen events: 92000, curr avg fear: 0.53
# Current I pop: 58, Current R pop: 55, Saved events: 461, Seen events: 92200, curr avg fear: 0.53
# Current I pop: 59, Current R pop: 55, Saved events: 462, Seen events: 92400, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 463, Seen events: 92600, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 464, Seen events: 92800, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 465, Seen events: 93000, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 466, Seen events: 93200, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 467, Seen events: 93400, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 468, Seen events: 93600, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 469, Seen events: 93800, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 470, Seen events: 94000, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 471, Seen events: 94200, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 472, Seen events: 94400, curr avg fear: 0.54
# Current I pop: 59, Current R pop: 55, Saved events: 473, Seen events: 94600, curr avg fear: 0.54
# Current I pop: 58, Current R pop: 56, Saved events: 474, Seen events: 94800, curr avg fear: 0.54
# Current I pop: 58, Current R pop: 56, Saved events: 475, Seen events: 95000, curr avg fear: 0.54
# Current I pop: 58, Current R pop: 56, Saved events: 476, Seen events: 95200, curr avg fear: 0.54
# Current I pop: 58, Current R pop: 56, Saved events: 477, Seen events: 95400, curr avg fear: 0.54
# Current I pop: 58, Current R pop: 56, Saved events: 478, Seen events: 95600, curr avg fear: 0.54
# Current I pop: 58, Current R pop: 56, Saved events: 479, Seen events: 95800, curr avg fear: 0.54
# Current I pop: 58, Current R pop: 56, Saved events: 480, Seen events: 96000, curr avg fear: 0.54
# Current I pop: 57, Current R pop: 57, Saved events: 481, Seen events: 96200, curr avg fear: 0.54
# Current I pop: 57, Current R pop: 57, Saved events: 482, Seen events: 96400, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 483, Seen events: 96600, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 484, Seen events: 96800, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 485, Seen events: 97000, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 486, Seen events: 97200, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 487, Seen events: 97400, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 488, Seen events: 97600, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 489, Seen events: 97800, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 490, Seen events: 98000, curr avg fear: 0.54
# Current I pop: 56, Current R pop: 58, Saved events: 491, Seen events: 98200, curr avg fear: 0.54
# Current I pop: 57, Current R pop: 58, Saved events: 492, Seen events: 98400, curr avg fear: 0.54
# Current I pop: 57, Current R pop: 58, Saved events: 493, Seen events: 98600, curr avg fear: 0.54
# Current I pop: 58, Current R pop: 58, Saved events: 494, Seen events: 98800, curr avg fear: 0.54
# Current I pop: 57, Current R pop: 59, Saved events: 495, Seen events: 99000, curr avg fear: 0.54
# Current I pop: 57, Current R pop: 59, Saved events: 496, Seen events: 99200, curr avg fear: 0.54
# Current I pop: 57, Current R pop: 59, Saved events: 497, Seen events: 99400, curr avg fear: 0.54
# Current I pop: 57, Current R pop: 59, Saved events: 498, Seen events: 99600, curr avg fear: 0.54
# ...
# Current I pop: 68, Current R pop: 146, Saved events: 1244, Seen events: 248800, curr avg fear: 0.59
# Current I pop: 68, Current R pop: 146, Saved events: 1245, Seen events: 249000, curr avg fear: 0.59
# Current I pop: 67, Current R pop: 147, Saved events: 1246, Seen events: 249200, curr avg fear: 0.59
# Current I pop: 67, Current R pop: 147, Saved events: 1247, Seen events: 249400, curr avg fear: 0.59
# Current I pop: 67, Current R pop: 147, Saved events: 1248, Seen events: 249600, curr avg fear: 0.59
# Current I pop: 67, Current R pop: 147, Saved events: 1249, Seen events: 249800, curr avg fear: 0.59
# Current I pop: 67, Current R pop: 147, Saved events: 1250, Seen events: 250000, curr avg fear: 0.59
# Current I pop: 66, Current R pop: 148, Saved events: 1251, Seen events: 250200, curr avg fear: 0.59
# Current I pop: 66, Current R pop: 148, Saved events: 1252, Seen events: 250400, curr avg fear: 0.59
# Current I pop: 66, Current R pop: 148, Saved events: 1253, Seen events: 250600, curr avg fear: 0.59
# Current I pop: 66, Current R pop: 148, Saved events: 1254, Seen events: 250800, curr avg fear: 0.59
# Current I pop: 66, Current R pop: 148, Saved events: 1255, Seen events: 251000, curr avg fear: 0.59
# Current I pop: 66, Current R pop: 148, Saved events: 1256, Seen events: 251200, curr avg fear: 0.59
# Current I pop: 66, Current R pop: 148, Saved events: 1257, Seen events: 251400, curr avg fear: 0.59
# Current I pop: 67, Current R pop: 148, Saved events: 1258, Seen events: 251600, curr avg fear: 0.59
# Current I pop: 68, Current R pop: 148, Saved events: 1259, Seen events: 251800, curr avg fear: 0.59
# Current I pop: 68, Current R pop: 148, Saved events: 1260, Seen events: 252000, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 148, Saved events: 1261, Seen events: 252200, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 148, Saved events: 1262, Seen events: 252400, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 148, Saved events: 1263, Seen events: 252600, curr avg fear: 0.59
# Current I pop: 70, Current R pop: 148, Saved events: 1264, Seen events: 252800, curr avg fear: 0.59
# Current I pop: 70, Current R pop: 148, Saved events: 1265, Seen events: 253000, curr avg fear: 0.59
# Current I pop: 70, Current R pop: 148, Saved events: 1266, Seen events: 253200, curr avg fear: 0.59
# Current I pop: 70, Current R pop: 148, Saved events: 1267, Seen events: 253400, curr avg fear: 0.59
# Current I pop: 70, Current R pop: 148, Saved events: 1268, Seen events: 253600, curr avg fear: 0.59
# Current I pop: 71, Current R pop: 148, Saved events: 1269, Seen events: 253800, curr avg fear: 0.59
# Current I pop: 71, Current R pop: 148, Saved events: 1270, Seen events: 254000, curr avg fear: 0.59
# Current I pop: 70, Current R pop: 149, Saved events: 1271, Seen events: 254200, curr avg fear: 0.59
# Current I pop: 70, Current R pop: 149, Saved events: 1272, Seen events: 254400, curr avg fear: 0.59
# Current I pop: 70, Current R pop: 149, Saved events: 1273, Seen events: 254600, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1274, Seen events: 254800, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1275, Seen events: 255000, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1276, Seen events: 255200, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1277, Seen events: 255400, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1278, Seen events: 255600, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1279, Seen events: 255800, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1280, Seen events: 256000, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1281, Seen events: 256200, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1282, Seen events: 256400, curr avg fear: 0.59
# Current I pop: 69, Current R pop: 150, Saved events: 1283, Seen events: 256600, curr avg fear: 0.58
# Current I pop: 69, Current R pop: 150, Saved events: 1284, Seen events: 256800, curr avg fear: 0.58
# Current I pop: 69, Current R pop: 150, Saved events: 1285, Seen events: 257000, curr avg fear: 0.58
# Current I pop: 70, Current R pop: 150, Saved events: 1286, Seen events: 257200, curr avg fear: 0.58
# Current I pop: 70, Current R pop: 150, Saved events: 1287, Seen events: 257400, curr avg fear: 0.58
# Current I pop: 70, Current R pop: 150, Saved events: 1288, Seen events: 257600, curr avg fear: 0.58
# Current I pop: 70, Current R pop: 150, Saved events: 1289, Seen events: 257800, curr avg fear: 0.58
# Current I pop: 70, Current R pop: 150, Saved events: 1290, Seen events: 258000, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 150, Saved events: 1291, Seen events: 258200, curr avg fear: 0.59
# Current I pop: 71, Current R pop: 150, Saved events: 1292, Seen events: 258400, curr avg fear: 0.59
# Current I pop: 72, Current R pop: 150, Saved events: 1293, Seen events: 258600, curr avg fear: 0.59
# Current I pop: 72, Current R pop: 150, Saved events: 1294, Seen events: 258800, curr avg fear: 0.59
# Current I pop: 72, Current R pop: 150, Saved events: 1295, Seen events: 259000, curr avg fear: 0.59
# Current I pop: 72, Current R pop: 150, Saved events: 1296, Seen events: 259200, curr avg fear: 0.59
# Current I pop: 71, Current R pop: 151, Saved events: 1297, Seen events: 259400, curr avg fear: 0.59
# Current I pop: 71, Current R pop: 151, Saved events: 1298, Seen events: 259600, curr avg fear: 0.59
# Current I pop: 71, Current R pop: 151, Saved events: 1299, Seen events: 259800, curr avg fear: 0.59
# Current I pop: 71, Current R pop: 151, Saved events: 1300, Seen events: 260000, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1301, Seen events: 260200, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1302, Seen events: 260400, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1303, Seen events: 260600, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1304, Seen events: 260800, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1305, Seen events: 261000, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1306, Seen events: 261200, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1307, Seen events: 261400, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1308, Seen events: 261600, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 151, Saved events: 1309, Seen events: 261800, curr avg fear: 0.58
# Current I pop: 72, Current R pop: 151, Saved events: 1310, Seen events: 262000, curr avg fear: 0.58
# Current I pop: 72, Current R pop: 151, Saved events: 1311, Seen events: 262200, curr avg fear: 0.58
# Current I pop: 73, Current R pop: 151, Saved events: 1312, Seen events: 262400, curr avg fear: 0.58
# Current I pop: 73, Current R pop: 151, Saved events: 1313, Seen events: 262600, curr avg fear: 0.58
# Current I pop: 73, Current R pop: 151, Saved events: 1314, Seen events: 262800, curr avg fear: 0.58
# Current I pop: 72, Current R pop: 152, Saved events: 1315, Seen events: 263000, curr avg fear: 0.58
# Current I pop: 71, Current R pop: 153, Saved events: 1316, Seen events: 263200, curr avg fear: 0.58
# Current I pop: 72, Current R pop: 153, Saved events: 1317, Seen events: 263400, curr avg fear: 0.58
# Current I pop: 72, Current R pop: 153, Saved events: 1318, Seen events: 263600, curr avg fear: 0.58
# Current I pop: 72, Current R pop: 153, Saved events: 1319, Seen events: 263800, curr avg fear: 0.58
# Current I pop: 72, Current R pop: 153, Saved events: 1320, Seen events: 264000, curr avg fear: 0.58
# Current I pop: 72, Current R pop: 153, Saved events: 1321, Seen events: 264200, curr avg fear: 0.58
# Current I pop: 73, Current R pop: 153, Saved events: 1322, Seen events: 264400, curr avg fear: 0.58
# Current I pop: 73, Current R pop: 153, Saved events: 1323, Seen events: 264600, curr avg fear: 0.58
# Current I pop: 73, Current R pop: 153, Saved events: 1324, Seen events: 264800, curr avg fear: 0.58
# Current I pop: 73, Current R pop: 153, Saved events: 1325, Seen events: 265000, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 153, Saved events: 1326, Seen events: 265200, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 153, Saved events: 1327, Seen events: 265400, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 153, Saved events: 1328, Seen events: 265600, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 153, Saved events: 1329, Seen events: 265800, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 153, Saved events: 1330, Seen events: 266000, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 153, Saved events: 1331, Seen events: 266200, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 154, Saved events: 1332, Seen events: 266400, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 155, Saved events: 1333, Seen events: 266600, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 155, Saved events: 1334, Seen events: 266800, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 155, Saved events: 1335, Seen events: 267000, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 155, Saved events: 1336, Seen events: 267200, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 156, Saved events: 1337, Seen events: 267400, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 156, Saved events: 1338, Seen events: 267600, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 156, Saved events: 1339, Seen events: 267800, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 156, Saved events: 1340, Seen events: 268000, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 156, Saved events: 1341, Seen events: 268200, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 156, Saved events: 1342, Seen events: 268400, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 156, Saved events: 1343, Seen events: 268600, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 156, Saved events: 1344, Seen events: 268800, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 156, Saved events: 1345, Seen events: 269000, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 156, Saved events: 1346, Seen events: 269200, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 157, Saved events: 1347, Seen events: 269400, curr avg fear: 0.58
# Current I pop: 75, Current R pop: 157, Saved events: 1348, Seen events: 269600, curr avg fear: 0.58
# Current I pop: 74, Current R pop: 158, Saved events: 1349, Seen events: 269800, curr avg fear: 0.58
# Current I pop: 77, Current R pop: 158, Saved events: 1350, Seen events: 270000, curr avg fear: 0.58
# Current I pop: 78, Current R pop: 158, Saved events: 1351, Seen events: 270200, curr avg fear: 0.58
# Current I pop: 79, Current R pop: 159, Saved events: 1352, Seen events: 270400, curr avg fear: 0.58
# Current I pop: 79, Current R pop: 159, Saved events: 1353, Seen events: 270600, curr avg fear: 0.58
# Current I pop: 79, Current R pop: 159, Saved events: 1354, Seen events: 270800, curr avg fear: 0.58
# Current I pop: 79, Current R pop: 159, Saved events: 1355, Seen events: 271000, curr avg fear: 0.58
# Current I pop: 80, Current R pop: 159, Saved events: 1356, Seen events: 271200, curr avg fear: 0.58
# Current I pop: 80, Current R pop: 159, Saved events: 1357, Seen events: 271400, curr avg fear: 0.58
# Current I pop: 80, Current R pop: 159, Saved events: 1358, Seen events: 271600, curr avg fear: 0.58
# Current I pop: 80, Current R pop: 159, Saved events: 1359, Seen events: 271800, curr avg fear: 0.58
# Current I pop: 80, Current R pop: 159, Saved events: 1360, Seen events: 272000, curr avg fear: 0.58
# Current I pop: 81, Current R pop: 159, Saved events: 1361, Seen events: 272200, curr avg fear: 0.58
# Current I pop: 82, Current R pop: 159, Saved events: 1362, Seen events: 272400, curr avg fear: 0.58
# Current I pop: 82, Current R pop: 159, Saved events: 1363, Seen events: 272600, curr avg fear: 0.58
# Current I pop: 81, Current R pop: 160, Saved events: 1364, Seen events: 272800, curr avg fear: 0.58
# Current I pop: 83, Current R pop: 160, Saved events: 1365, Seen events: 273000, curr avg fear: 0.58
# Current I pop: 83, Current R pop: 160, Saved events: 1366, Seen events: 273200, curr avg fear: 0.58
# Current I pop: 84, Current R pop: 160, Saved events: 1367, Seen events: 273400, curr avg fear: 0.58
# Current I pop: 84, Current R pop: 160, Saved events: 1368, Seen events: 273600, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 160, Saved events: 1369, Seen events: 273800, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 160, Saved events: 1370, Seen events: 274000, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 160, Saved events: 1371, Seen events: 274200, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 160, Saved events: 1372, Seen events: 274400, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 160, Saved events: 1373, Seen events: 274600, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 160, Saved events: 1374, Seen events: 274800, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 160, Saved events: 1375, Seen events: 275000, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 161, Saved events: 1376, Seen events: 275200, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 161, Saved events: 1377, Seen events: 275400, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 162, Saved events: 1378, Seen events: 275600, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 162, Saved events: 1379, Seen events: 275800, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 162, Saved events: 1380, Seen events: 276000, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 163, Saved events: 1381, Seen events: 276200, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 164, Saved events: 1382, Seen events: 276400, curr avg fear: 0.58
# Current I pop: 84, Current R pop: 166, Saved events: 1383, Seen events: 276600, curr avg fear: 0.58
# Current I pop: 84, Current R pop: 166, Saved events: 1384, Seen events: 276800, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 166, Saved events: 1385, Seen events: 277000, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 166, Saved events: 1386, Seen events: 277200, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 166, Saved events: 1387, Seen events: 277400, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 166, Saved events: 1388, Seen events: 277600, curr avg fear: 0.58
# Current I pop: 86, Current R pop: 166, Saved events: 1389, Seen events: 277800, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 167, Saved events: 1390, Seen events: 278000, curr avg fear: 0.58
# Current I pop: 84, Current R pop: 168, Saved events: 1391, Seen events: 278200, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 168, Saved events: 1392, Seen events: 278400, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 168, Saved events: 1393, Seen events: 278600, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 168, Saved events: 1394, Seen events: 278800, curr avg fear: 0.58
# Current I pop: 85, Current R pop: 168, Saved events: 1395, Seen events: 279000, curr avg fear: 0.58
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 tmax = 50
#       2 modulo = 200
# ----> 3 t, data,fears,event_types = custom_SIR_with_fear(G, beta, gammaIR, r_beta, mu_f, alpha,delta, mu_fear_dist, sigma_fear_dist,fear_threshold,tmax,modulo)
#
# Cell In[7], line 88, in custom_SIR_with_fear(G, beta, gammaIR, r_beta, mu_f, alpha, delta, mu_fear_dist, sigma_fear_dist, fear_threshold, tmax, modulo)
#      85 a = age[i]
#      86 neigh = neighbors[i]
# ---> 88 Sf_neigh  = [j for j in neigh if status[j] == 'Sf']
#      90 if Sf_neigh:
#      91     # Sf + S -> 2S
#      92     events.append(('SfS', (i, Sf_neigh)))
#
# KeyboardInterrupt:

# %%
ev = np.unique(np.array([event for event in event_types]), return_counts=True)
ev

# %%
I = []
R = []
S = []
Sf = []
for time in range(len(t)):
    I.append(len(np.where(np.array(list(data[time].values()))=='I')[0])) 
    R.append(len(np.where(np.array(list(data[time].values()))=='R')[0]))
    S.append(len(np.where(np.array(list(data[time].values()))=='S')[0]))
    Sf.append(len(np.where(np.array(list(data[time].values()))=='Sf')[0]))

# %%
plt.plot(t,S,label='S')
plt.plot(t,Sf,label='Sf', color ='lightblue')
plt.plot(t,np.array(S)+np.array(Sf),label='S+Sf', color ='navy')
plt.plot(t,I,label='I', color = 'red')
plt.plot(t,R,label='R', color= 'green')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Populations')
plt.grid(alpha = 0.6)
path = folder_path+f'/SIR.png'
plt.savefig(path)
plt.show()

# %%
# only I plot (smooth)
max_time = len(t)
time_bins = np.arange(0,max(t),int(max(t))/100)
I = np.array(I)

# Calculate bin averages
binned_I = []
binned_time = []

for i in range(len(time_bins) - 1):
    # Find indices where t falls within current bin
    mask = (t >= time_bins[i]) & (t < time_bins[i+1])
    
    # If there are data points in this bin, calculate average
    if np.sum(mask) > 0:
        binned_I.append(np.mean(I[mask]))
        binned_time.append((time_bins[i] + time_bins[i+1]) / 2)  # Use bin center

# Convert to arrays
binned_time = np.array(binned_time)
binned_I = np.array(binned_I)

# Plot
plt.plot(binned_time, binned_I, color='red', label='I', linewidth=2)
plt.xlabel('time')
plt.ylabel('I')
plt.legend()
plt.grid(alpha=0.6)
path = folder_path + f'/Ipop_vs_time.png'
plt.savefig(path)
plt.show()

# %%
avg_fear = np.zeros(len(fears))
std_fear = np.zeros(len(fears))
for i in range(len(fears)):
    fear_values = np.array([fear for fear in fears[i].values()])
    #print(fear_values)
    avg_fear[i]=np.mean(fear_values)
    std_fear[i]=np.std(fear_values)
times = np.arange(0,len(fears),1)
plt.plot(times,avg_fear, label = 'avg fear in pop')
plt.plot(times,avg_fear + std_fear, label = '1 std',color='lightblue')
plt.plot(times,avg_fear - std_fear,color='lightblue')
plt.xlabel('timestep')
plt.ylabel('fear')
plt.ylim(0,1)
plt.hlines(fear_threshold,xmin = times[0],xmax=times[-1],ls='--',color = 'red',label='fear threshold')
plt.grid(alpha = 0.6)
plt.legend()
path = folder_path+f'/fear_vs_time.png'
plt.savefig(path)
plt.show()

# %%
age_classes = dict(G.nodes(data = 'age_class'))
avg_fear = np.zeros((len(fears),3))
age = [age for age in age_classes.values()]
for i in range(len(fears)):
    fear_values = np.array([fear for fear in fears[i].values()])
    counter = np.zeros(3)
    for value_idx in range(len(fear_values)):
        if(age[value_idx] == 'A'):
            avg_fear[i,0] += fear_values[value_idx]
            counter[0]+=1
        if(age[value_idx] == 'E'):
            avg_fear[i,1] += fear_values[value_idx]
            counter[1]+=1
        if(age[value_idx] == 'Y'):
            avg_fear[i,2] += fear_values[value_idx]
            counter[2]+=1

    # here compute the average at timestep i for all 3 classes
    avg_fear[i,:] = avg_fear[i,:] / counter


plt.plot(times,avg_fear[:,0],label='mean fear class A')
plt.plot(times,avg_fear[:,1],label='mean fear class E')
plt.plot(times,avg_fear[:,2],label='mean fear class Y')
plt.legend()
plt.grid(alpha = 0.6)
plt.xlabel('timestep')
plt.ylabel('fear')
path = folder_path+f'/fear_vs_time_byclass.png'
plt.show()

# %%
avg_fear = np.zeros(len(fears))
std_fear = np.zeros(len(fears))
for i in range(len(fears)):
    fear_values = np.array([fear for fear in fears[i].values()])
    #print(fear_values)
    avg_fear[i]=np.mean(fear_values)
    std_fear[i]=np.std(fear_values)

# %%
color = np.arange(0,len(I),1)
plt.scatter(I,avg_fear,c = color,cmap = 'viridis', s = 5)
plt.xlabel('I population')
plt.ylabel('average fear')
plt.colorbar(label='time')
plt.grid(alpha = 0.6)
path = folder_path+f'/fear_vs_I_samu.png'
plt.savefig(path)
plt.show()

# %%
# times of snapshot
if gif_flag:
    snapshot_skip = 100
    for i,time in enumerate(t):
        if i%snapshot_skip==0:
            L = nx.Graph()
            L.add_nodes_from(data[i])
            L.add_edges_from(G.edges)
            nx.set_node_attributes(L, values=data[i], name='disease_state')
            nx.set_node_attributes(L, values=fears[i], name='fear')
            nx.set_node_attributes(L, values=age_classes, name='age_class')
        
            # select pos once for all plots
            if i == 0:
                pos = nx.arf_layout(G)
            
            # make a folder
            os.makedirs(folder_path+f"/frames", exist_ok=True)
            filepath = folder_path+f'/frames/network_status_time_{i}.png'
            save_plot(L,i,filepath,pos)

# %%
if gif_flag:
    # produce GIF
    # make a folder
    os.makedirs(folder_path+f"/gifs", exist_ok=True)
    frames = []
    for i,time in enumerate(t):
        if i%snapshot_skip==0:
            img = Image.open(folder_path+f'/frames/network_status_time_{i}.png')
            frames.append(img)
            
            frames[0].save(folder_path+f"/gifs/network_gif.gif", 
                           save_all=True, 
                           append_images=frames[1:], 
                           duration=900,  # milliseconds per frame
                           loop=0)
        
    print("GIF saved as network_animation.gif")

# %% [markdown]
# # Study of the epidemic

# %%
# t data fears age_classes
dt = 0.8 # time unit
time_bins = np.arange(0,max(t)+dt,dt)

# arrays
new_infections = np.zeros(len(time_bins)-1)
new_feared = np.zeros(len(time_bins)-1)

# for each interval
for i in range(len(time_bins) - 1):
    t_start = time_bins[i]       # time value start
    t_end = time_bins[i + 1]     # time value end
        
    # find events in this interval
    events_in_interval = [(t, s, f) for t, s, f in zip(t, data, fears) 
                          if t_start <= t < t_end]
        
    if len(events_in_interval) >= 2:
        
        for j in range(1, len(events_in_interval)):
            prev_status = events_in_interval[j-1][1]
            curr_status = events_in_interval[j][1]
                
            for node in prev_status:
                if prev_status[node] in ['S', 'Sf'] and curr_status[node] == 'I':
                    new_infections[i] += 1
                if prev_status[node] == 'S' and curr_status[node] == 'Sf':
                    new_feared[i] += 1
                elif prev_status[node] == 'Sf' and curr_status[node] == 'S':
                    new_feared[i] -= 1

# %% [markdown]
# ## Fear level vs being infected

# %%
infection_fears = [] # to save data

for time in range(1,len(data)):
    # time index that runs across all timesteps
    previous_states = [state for state in data[time-1].values()]      ## prev states  
    curr_states = [state for state in data[time].values()]            ## curr states
    previous_fears = [fear for fear in fears[time-1].values()]
    
    for node_idx in range(len(previous_states)):
        # infection check
        if(previous_states[node_idx] in ['S','Sf'] and curr_states[node_idx] == 'I'):
            # save fear data
            infection_fears.append(previous_fears[node_idx])

bins = np.arange(0,1,0.05)
counts, _, _ = plt.hist(infection_fears,bins=bins,label ='p of getting I vs fear')
plt.vlines(fear_threshold,ymin = min(counts)-0.2,ymax=max(counts)+0.2,label='fear_threshold', ls = '--', color = 'red')
plt.legend()
plt.xlabel('fear')
plt.ylabel('# of infections')
p_left = np.sum(counts[np.where(bins<fear_threshold)[0]]) / np.sum(counts)
p_right = 1. - p_left

plt.title('Fear when infected histogram')
plt.text(0.,max(counts)*0.1,s=f'prob left threshold = {round(p_left,3)}', bbox=dict(boxstyle='square',facecolor='white',edgecolor='black'))
plt.text(0.55,max(counts)*0.1,s=f'prob right threshold = {round(p_right,3)}', bbox=dict(boxstyle='square',facecolor='white',edgecolor='black'))
plt.savefig(folder_path+"/fear_level_prob_of_getting_I.png")
plt.show()

# %% [markdown]
# ## Fear vs new infections

# %%
tot_feared = np.cumsum(new_feared)
colors = np.arange(len(tot_feared))
plt.scatter(tot_feared,new_infections, c = colors, cmap = 'viridis',label='new infections vs feared')
#plt.plot(time_bins[1:],tot_feared, label = 'total feared dt', ls = '--')
plt.legend()
plt.grid(alpha = 0.6)
plt.xlabel(f'total feared')
plt.ylabel(f'new infections')
#plt.xscale('log')
plt.colorbar(label='Time progression')
#plt.yscale('log')
plt.savefig(folder_path+f"/newI_vs_totalFear_plot.png")
plt.show()

# %%
# percentage of infected per population
final_snapshot = zip(data[-1].values(),age_classes.values())
tot_A = len(np.where(np.array([clas for clas in age_classes.values()])=='A')[0])
tot_E = len(np.where(np.array([clas for clas in age_classes.values()])=='E')[0])
tot_Y = len(np.where(np.array([clas for clas in age_classes.values()])=='Y')[0])
final_ar_A = 0
final_ar_E = 0    # final attack rates
final_ar_Y = 0 

for i,j in final_snapshot:
    if (i == 'R' and j == 'A'):
        final_ar_A += 1
    if (i == 'R' and j == 'E'):
        final_ar_E += 1
    if (i == 'R' and j == 'Y'):
        final_ar_Y += 1
final_attack_rates_per_class = [final_ar_A/tot_A,final_ar_E/tot_E,final_ar_Y/tot_Y]
final_attack_rates_per_class

# %%
# trend of infected per population
trends = np.zeros((len(data),3))
for t in range(len(data)):
    snapshot = zip(data[t].values(),age_classes.values())
    tot_A = len(np.where(np.array([clas for clas in age_classes.values()])=='A')[0])
    tot_E = len(np.where(np.array([clas for clas in age_classes.values()])=='E')[0])
    tot_Y = len(np.where(np.array([clas for clas in age_classes.values()])=='Y')[0])
    final_ar_A = 0
    final_ar_E = 0    # final attack rates
    final_ar_Y = 0 
    
    for i,j in snapshot:
        if (i in ['I','R'] and j == 'A'):
            final_ar_A += 1
        if (i in ['I','R'] and j == 'E'):
            final_ar_E += 1
        if (i in ['I','R'] and j == 'Y'):
            final_ar_Y += 1
    final_attack_rates_per_class = [final_ar_A/tot_A,final_ar_E/tot_E,final_ar_Y/tot_Y]
    trends[t,:] = final_attack_rates_per_class
    
# plot logic
plt.plot(times,trends[:,0]*100,label ='A')
plt.plot(times,trends[:,1]*100,label ='E')
plt.plot(times,trends[:,2]*100,label ='Y')
plt.xlabel('event')
plt.ylabel('% of pop infected')
plt.legend()
plt.grid(alpha = 0.6)
plt.savefig(folder_path + "/perc_pop_vs_time_class.png")

plt.show()

# %%
# infections vs degree
deg_np = np.array([deg[1] for deg in G.degree])
unique_degrees = np.unique(deg_np)
final_states = np.array([state for state in data[-1].values()])

prob_R_given_k = []  
degrees_for_plot = []

for k in unique_degrees:
    nodes_with_degree_k = (deg_np == k)
    # how many are R
    num_R = np.sum(final_states[nodes_with_degree_k] == 'R')  
    total = np.sum(nodes_with_degree_k)
    # probability
    prob_R_given_k.append(num_R / total)
    degrees_for_plot.append(k)

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(degrees_for_plot, prob_R_given_k)
plt.xlabel('Degree k')
plt.ylabel('P(R | k)')
plt.xscale('log')
plt.title('Probability of being Recovered vs Degree')
plt.grid(alpha=0.6)
plt.savefig(folder_path + "/prob_R_vs_degree.png")
plt.show()

# %%
# epidemic size (fraction of N that is R at the end of time)
es = R[-1] / len(G.nodes)
# reproductive ratio of fear
alpha_np = np.array([val for val in alpha.values()])
beta_np = np.array([val for val in beta.values()])
muf_np = np.array([val for val in mu_f.values()])
gammaIR_np = np.array([val for val in gammaIR.values()])
Rf = alpha_np * beta_np / muf_np
# basic reproductive ratio (general def on networks)
deg_np = np.array([deg[1] for deg in G.degree])
deg2_np = np.array([deg[1]**2 for deg in G.degree])
R0 = (beta_np / gammaIR_np) * (np.mean(deg2_np) - np.mean(deg_np)) / np.mean(deg_np)
# timestep of peak infection
timestep_max_I = np.argmax(I)
# timestep of peak fear
timestep_max_f = np.argmax(avg_fear)

# %%
events, counts = np.unique(event_types, return_counts=True)
for event, count in zip(events,counts):
    print(event,count)

# %%
log_path = folder_path+f'/event_log.txt'
with open(log_path,"w") as text_file:
    print(f"Event type: ###",file = text_file)
    print(f"IR recovery: {counts[np.where(events == 'IR')[0]]}",file = text_file)
    print(f"Fear spontaneous S->Sf: {counts[np.where(events == 'fear')[0]]}",file = text_file)
    print(f"Fear removal Sf+R -> S+R or Sf+S-> 2S: {counts[np.where(events == 'SfR')[0]]}",file = text_file)
    print(f"Fear transmission Sf+S->2S: {counts[np.where(events == 'SfS')[0]]}",file = text_file)
    print(f"Fear removal boredom Sf -> S: {counts[np.where(events == 'fear_boredom')[0]]}",file = text_file)
    print(f"Disease transmission S+I->2I: {counts[np.where(events == 'SI')[0]]}",file = text_file)
    print(f"Disease transmission Sf+I->2I: {counts[np.where(events == 'SfI')[0]]}",file = text_file)
    print(f"OTHER",file = text_file)
    print(f"Epidemic size (total fraction): {es}",file = text_file)
    print(f"Rf by age class: {Rf}",file = text_file)
    print(f"R0 by age class: {R0}",file = text_file)
    print(f"timestep of max I: {timestep_max_I}",file = text_file)
    print(f"timestep of max fear: {timestep_max_f}",file = text_file)
    print(f"Final attack rates per class: {final_attack_rates_per_class}",file = text_file)
